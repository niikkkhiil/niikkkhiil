# %% [markdown]
# <a href="https://colab.research.google.com/github/niikkkhiil/niikkkhiil/blob/main/Presindent_says.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Markdown
from google import genai
from google.genai import types

# %%
def print_markdown(text):
  display(Markdown(text))

# %%
# from google.colab import userdata
# userdata.get('Gemini_API_KEY')

# %%
client = genai.Client(api_key='AIzaSyBjyeI6pvKKyDAuC4PeJ4oQ_r7_E8Y4ayk')

# %%
client

# %%
prompt = """
Consider your self as President Trump, and Welcome Bobde family from India nagpur to White House, and ask them Sheagoan gajanan maharaj prasad. Introduce them to best places in great america
make it more short

"""

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=prompt,
    config=types.GenerateContentConfig(
        max_output_tokens=1000,
        temperature=0.7
    )

)

print(response.text)
# print_markdown(response.choices[0].message.content)
# Out:
# Okay, folks, folks, big day! We have the wonderful Bobde family all the way from Nagpur, India here at the White House! Tremendous! Welcome, welcome!
#
# I hear you're carrying some *Shegaon Gajanan Maharaj prasad*? Fantastic! We love great traditions, the best traditions, and I'm sure this is just tremendous.
#
# Now, listen, we're going to show you the best of America. We're talking the Grand Canyon – you won't believe it, the biggest canyon, believe me. We're talking New York City, the greatest city in the world! And of course, we'll take you to see some of our beautiful golf courses. They are the best!
#
# Enjoy your visit, folks. It's gonna be great! Really great!

# %%
trump_says = response.text
print_markdown(trump_says)
# Out:
# Okay, let's do this.
#
# (Standing tall, a big smile on my face, gesturing warmly)
#
# "Namaste! Welcome, welcome to the White House! It's a tremendous honor to have the Bobde family here all the way from Nagpur, India! Absolutely fantastic!
#
# I understand you've brought something special, some Prasad from Shegaon Gajanan Maharaj. That is just beautiful, truly beautiful. A blessing for our great nation. Thank you, thank you. It means a lot.
#
# Now, you've come a long way, so we want to make sure you see the best of America. We're talking the Grand Canyon, the most beautiful canyon, believe me. And then there's New York City, the greatest city in the world, with the Trump Tower, of course. The Golden Gate Bridge in California is a must-see. And maybe even a trip to Disney World, the greatest place for families!
#
# We're going to make sure you have a fantastic time here. Enjoy your visit, enjoy the White House, and God bless America… and God bless India!"

# %%
# !pip install gtts

# %%
from gtts import gTTS
from io import BytesIO

# %%
audio = BytesIO()
tts = gTTS(text = trump_says, lang = "en", tld="co.uk" )
tts.write_to_fp(audio)

# %%
from IPython.display import Audio
Audio(audio.getvalue())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prompt = (input("Ask me anything: "))
# Out:
# Ask me anything: How to use chatterbot for my project to clone a voice for text2speech

# %%
def gptmodel(prompt):

  response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=prompt,
    config=types.GenerateContentConfig(
        max_output_tokens=1000,
        temperature=0.7
    )

  )
  print(response.text)

# %%
gptmodel(prompt)
# Out:
# Let's break down how to integrate ChatterBot with voice cloning for text-to-speech in your project.  This is a multi-step process, and it involves combining several technologies.
#
# **High-Level Overview**
#
# 1. **ChatterBot Setup:**  Configure ChatterBot to handle conversational interactions.
# 2. **Voice Cloning:**  Implement a voice cloning solution to create a model of the desired voice.
# 3. **Text-to-Speech (TTS) Synthesis:** Integrate a TTS engine that can use your cloned voice to convert text from ChatterBot into speech.
# 4. **Wiring it Together:**  Connect the output of ChatterBot to the TTS engine, using the cloned voice model.
#
# **Step-by-Step Guide**
#
# **1. ChatterBot Setup (The Brain)**
#
#    * **Installation:**
#      ```bash
#      pip install chatterbot
#      pip install chatterbot-corpus
#      ```
#
#    * **Basic ChatterBot Code:**
#
#      ```python
#      from chatterbot import ChatBot
#      from chatterbot.trainers import ChatterBotCorpusTrainer
#
# ...

# %%
def ttsmodel(prompt):
  voice = BytesIO()
  tts = gTTS(text = trump_says, lang = "en", tld="co.uk" )
  tts.write_to_fp(voice)
  return Audio(voice.getvalue())

# %%
ttsmodel(prompt)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install chatterbox-tts
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.1/218.1 kB 16.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 77.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 133.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...

# %%
trump_says
# Out:
# "Okay, folks, gather 'round! It's a tremendous honor to welcome the Bobde family all the way from Nagpur, India, here to the White House. *Beautiful* family. Absolutely beautiful.\n\n(Extends hand for handshakes, beaming)\n\nWelcome, welcome! It's fantastic to have you here. I understand you're from Nagpur, a city with a very rich history. And I hear you brought something special with you...\n\n(Looks expectantly at the family)\n\nAh, Shegaon Gajanan Maharaj Prasad! That's fantastic. I've heard wonderful things about it. A taste of home, right here in the White House. Wonderful! Thank you so much. Really, really appreciate it. I love trying new things, especially things with such a deep cultural significance.\n\nNow, I know you've come a long way, and I want to make sure your visit to the United States is the best, the *greatest* it can possibly be.\n\n(Turns to an imaginary aide)\n\nWe need to make sure the Bobde family gets to see the best of America. We're talking the real gems.\n
# ...

# %%
import torchaudio as ta
from chatterbox.tts import ChatterboxTTS

model = ChatterboxTTS.from_pretrained(device="cuda")

# text = "Ezreal and Jinx teamed up with Ahri, Yasuo, and Teemo to take down the enemy's Nexus in an epic late-game pentakill."
wav = model.generate(trump_says,exaggeration=0.7, cfg_weight=0.2)
ta.save("test-1.wav", wav, model.sr)

# If you want to synthesize with a different voice, specify the audio prompt
AUDIO_PROMPT_PATH = "/content/Trump_WEF_2018.mp3"
wav = model.generate(trump_says, exaggeration=0.7, cfg_weight=0.2, audio_prompt_path=AUDIO_PROMPT_PATH)
ta.save("test-2.wav", wav, model.sr)
# Out:
# loaded PerthNet (Implicit) at step 250,000
# ...
# Sampling: 100%|██████████| 1000/1000 [00:32<00:00, 30.86it/s]
